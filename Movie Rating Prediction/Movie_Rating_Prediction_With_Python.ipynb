# %% [markdown]
# # **Movie Rating Prediction With Python**
# ---
#                                                                  Name : VISHNU E
#                                                                  Organization : CodSoft
#                                                                  Date : 08/12/2024

# %% [markdown]
# ## **Problem Statement**
# ---
# To build a machine learning model that predicts movie ratings based on features like genre, director, and actors using regression techniques. By analyzing historical movie data, the model will provide insights into factors influencing ratings and enable accurate rating predictions.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv('IMDb Movies India.csv', encoding='latin-1')
df
# Out:
#                                      Name    Year Duration            Genre  \
# 0                                             NaN      NaN            Drama
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                             #Homecoming  (2021)   90 min   Drama, Musical
# 3                                 #Yaaram  (2019)  110 min  Comedy, Romance
# 4                       ...And Once Again  (2010)  105 min            Drama
# ...                                   ...     ...      ...              ...
# 15504                 Zulm Ko Jala Doonga  (1988)      NaN           Action
# 15505                               Zulmi  (1999)  129 min    Action, Drama
# 15506                           Zulmi Raj  (2005)      NaN           Action
# 15507                       Zulmi Shikari  (1988)      NaN           Action
# 15508                        Zulm-O-Sitam  (1998)  130 min    Action, Drama
#
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# summary of the dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15509 entries, 0 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      15509 non-null  object
#  1   Year      14981 non-null  object
#  2   Duration  7240 non-null   object
#  3   Genre     13632 non-null  object
#  4   Rating    7919 non-null   float64
#  5   Votes     7920 non-null   object
#  6   Director  14984 non-null  object
#  7   Actor 1   13892 non-null  object
#  8   Actor 2   13125 non-null  object
#  9   Actor 3   12365 non-null  object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ MB

# %%
# checking for null values

df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
# droping null values

df.dropna(inplace=True)
df
# Out:
#                                      Name    Year Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                                 #Yaaram  (2019)  110 min
# 5                    ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                               ...Yahaan  (2005)  142 min
# 8                      ?: A Question Mark  (2012)   82 min
# ...                                   ...     ...      ...
# 15493                              Zubaan  (2015)  115 min
# 15494                            Zubeidaa  (2001)  153 min
# 15503                     Zulm Ki Zanjeer  (1989)  125 min
# 15505                               Zulmi  (1999)  129 min
# 15508                        Zulm-O-Sitam  (1998)  130 min
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# ...

# %%
# checking for duplicate values

df.duplicated().sum()
# Out:
# 0

# %%
# Remove non-numeric characters (leave only digits)
# Convert the columns to string type first

df['Year'] = df['Year'].astype(str).str.replace(r'[^0-9]', '', regex=True)
df['Votes'] = df['Votes'].astype(str).str.replace(r'[^0-9]', '', regex=True)
df['Duration'] = df['Duration'].astype(str).str.replace(r'[^0-9]', '', regex=True)

# Convert the columns to numeric
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df['Votes'] = pd.to_numeric(df['Votes'], errors='coerce')
df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                            Genre  Rating  Votes         Director  \
# 1                          Drama     7.0      8    Gaurav Bakshi
# 3                Comedy, Romance     4.4     35       Ovais Khan
# 5         Comedy, Drama, Musical     4.7    827     Rahul Rawail
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5659 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      5659 non-null   object
#  1   Year      5659 non-null   int64
#  2   Duration  5659 non-null   int64
#  3   Genre     5659 non-null   object
#  4   Rating    5659 non-null   float64
#  5   Votes     5659 non-null   int64
#  6   Director  5659 non-null   object
#  7   Actor 1   5659 non-null   object
#  8   Actor 2   5659 non-null   object
#  9   Actor 3   5659 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 486.3+ KB

# %%
# df['Year'] = df['Year'].astype(str).str.replace(r'[()]', '', regex=True).astype(int)
# df['Duration'] = df['Duration'].astype(str).str.replace('min', '', regex=True).astype(int)
# df['Votes'] = df['Votes'].astype(str).str.replace(r'[,]', '', regex=True).astype(int)
# df['Votes'] = pd.to_numeric(df['Votes'].str.replace(r'[,]', '', regex=True), errors='coerce').astype(int)
# df

# %%
# splitting the 'Genre' column values

df['Genre'] = df['Genre'].str.split(', ')
df
# Out:
#                                      Name  Year  Duration  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109
# 3                                 #Yaaram  2019       110
# 5                    ...Aur Pyaar Ho Gaya  1997       147
# 6                               ...Yahaan  2005       142
# 8                      ?: A Question Mark  2012        82
# ...                                   ...   ...       ...
# 15493                              Zubaan  2015       115
# 15494                            Zubeidaa  2001       153
# 15503                     Zulm Ki Zanjeer  1989       125
# 15505                               Zulmi  1999       129
# 15508                        Zulm-O-Sitam  1998       130
#
#                              Genre  Rating  Votes         Director  \
# 1                          [Drama]     7.0      8    Gaurav Bakshi
# 3                [Comedy, Romance]     4.4     35       Ovais Khan
# ...

# %%
df = df.explode('Genre')
df
# Out:
#                                      Name  Year  Duration    Genre  Rating  \
# 1      #Gadhvi (He thought he was Gandhi)  2019       109    Drama     7.0
# 3                                 #Yaaram  2019       110   Comedy     4.4
# 3                                 #Yaaram  2019       110  Romance     4.4
# 5                    ...Aur Pyaar Ho Gaya  1997       147   Comedy     4.7
# 5                    ...Aur Pyaar Ho Gaya  1997       147    Drama     4.7
# ...                                   ...   ...       ...      ...     ...
# 15503                     Zulm Ki Zanjeer  1989       125    Drama     5.8
# 15505                               Zulmi  1999       129   Action     4.5
# 15505                               Zulmi  1999       129    Drama     4.5
# 15508                        Zulm-O-Sitam  1998       130   Action     6.2
# 15508                        Zulm-O-Sitam  1998       130    Drama     6.2
#
# ...

# %%
# df['Genre'].fillna(df['Genre'].mode()[0], inplace=True)
# df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11979 entries, 1 to 15508
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      11979 non-null  object
#  1   Year      11979 non-null  int64
#  2   Duration  11979 non-null  int64
#  3   Genre     11979 non-null  object
#  4   Rating    11979 non-null  float64
#  5   Votes     11979 non-null  int64
#  6   Director  11979 non-null  object
#  7   Actor 1   11979 non-null  object
#  8   Actor 2   11979 non-null  object
#  9   Actor 3   11979 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.0+ MB

# %%
# droping 'Name' column

df.drop(columns = 'Name', inplace = True)
df
# Out:
#        Year  Duration    Genre  Rating  Votes         Director       Actor 1  \
# 1      2019       109    Drama     7.0      8    Gaurav Bakshi  Rasika Dugal
# 3      2019       110   Comedy     4.4     35       Ovais Khan       Prateik
# 3      2019       110  Romance     4.4     35       Ovais Khan       Prateik
# 5      1997       147   Comedy     4.7    827     Rahul Rawail    Bobby Deol
# 5      1997       147    Drama     4.7    827     Rahul Rawail    Bobby Deol
# ...     ...       ...      ...     ...    ...              ...           ...
# 15503  1989       125    Drama     5.8     44  S.P. Muthuraman   Chiranjeevi
# 15505  1999       129   Action     4.5    655       Kuku Kohli  Akshay Kumar
# 15505  1999       129    Drama     4.5    655       Kuku Kohli  Akshay Kumar
# 15508  1998       130   Action     6.2     20     K.C. Bokadia    Dharmendra
# 15508  1998       130    Drama     6.2     20     K.C. Bokadia    Dharmendra
#
# ...

# %%
# creating new columns

from re import A

director_genre_mean_rating = df.groupby(['Director', 'Genre'])['Rating'].transform('mean')
df['Director_Genre_Specific'] = director_genre_mean_rating

actor1_mean_rating = df.groupby('Actor 1')['Rating'].transform('mean')
df['Actor1_Specific'] = actor1_mean_rating

actor2_mean_rating = df.groupby('Actor 2')['Rating'].transform('mean')
df['Actor2_Specific'] = actor2_mean_rating

actor3_mean_rating = df.groupby('Actor 3')['Rating'].transform('mean')
df['Actor3_Specific'] = actor3_mean_rating

director_actor_combo_mean_rating = df.groupby(['Director','Actor 1','Actor 2','Actor 3'])['Rating'].transform('mean')
df['Director_Actor_combo'] = actor3_mean_rating

df
# Out:
#        Year  Duration    Genre  Rating  Votes         Director       Actor 1  \
# 1      2019       109    Drama     7.0      8    Gaurav Bakshi  Rasika Dugal
# 3      2019       110   Comedy     4.4     35       Ovais Khan       Prateik
# 3      2019       110  Romance     4.4     35       Ovais Khan       Prateik
# 5      1997       147   Comedy     4.7    827     Rahul Rawail    Bobby Deol
# 5      1997       147    Drama     4.7    827     Rahul Rawail    Bobby Deol
# ...     ...       ...      ...     ...    ...              ...           ...
# 15503  1989       125    Drama     5.8     44  S.P. Muthuraman   Chiranjeevi
# 15505  1999       129   Action     4.5    655       Kuku Kohli  Akshay Kumar
# 15505  1999       129    Drama     4.5    655       Kuku Kohli  Akshay Kumar
# 15508  1998       130   Action     6.2     20     K.C. Bokadia    Dharmendra
# 15508  1998       130    Drama     6.2     20     K.C. Bokadia    Dharmendra
#
# ...

# %%
# correlation matrix of numerical features

numerical_columns = ['Year', 'Duration', 'Votes', 'Rating', 'Director_Genre_Specific', 'Actor1_Specific', 'Actor2_Specific', 'Actor3_Specific', 'Director_Actor_combo']
correlation_matrix = df[numerical_columns].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# pairplot of features

sns.pairplot(df)

# %%
# histogram of features

plt.figure(figsize = (30,28))
for i, col in enumerate(df[numerical_columns].columns,1):
    plt.subplot(5,5,i)
    sns.histplot(df[col], kde = True)
    plt.title(f'Distribution of {col}')

# %%
# statistical summary of the dataframe

df.describe()
# Out:
#                Year      Duration        Rating          Votes  \
# count  11979.000000  11979.000000  11979.000000   11979.000000
# mean    1996.099174    135.871024      5.879356    3335.405293
# std       19.314008     25.012586      1.374243   15305.935731
# min     1931.000000     21.000000      1.100000       5.000000
# 25%     1982.000000    120.000000      5.000000      41.000000
# 50%     2001.000000    137.000000      6.100000     213.000000
# 75%     2012.000000    152.000000      6.900000    1469.000000
# max     2021.000000    321.000000     10.000000  591417.000000
#
#        Director_Genre_Specific  Actor1_Specific  Actor2_Specific  \
# count             11979.000000     11979.000000     11979.000000
# mean                  5.879356         5.879356         5.879356
# std                   1.194723         1.001893         1.033034
# min                   1.400000         1.400000         1.600000
# 25%                   5.117045         5.285714         5.280000
# ...

# %%
# scaling features

from sklearn.preprocessing import StandardScaler

X = df[numerical_columns].drop(columns = 'Rating')
y = df['Rating']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# splitting the dataset

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Model Building and Model Evaluation

# %%
# model building and evaluation

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score


# Initialize models
models = {
    "Linear Regression": LinearRegression(),
    "Ridge Regression": Ridge(alpha=1.0),
    "Lasso Regression": Lasso(alpha=0.1),
    "Random Forest": RandomForestRegressor(n_estimators=100, random_state=42),
    "Decision Tree": DecisionTreeRegressor(random_state=42),
    "Gradient Boosting": GradientBoostingRegressor(random_state=42)
}

# Dictionary to store results
results = {
    "Model": [],
    "RMSE": [],
    "R2_Score": []
}

# Train and evaluate each model
for model_name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 = r2_score(y_test, y_pred)
    results["Model"].append(model_name)
    results["RMSE"].append(rmse)
    results["R2_Score"].append(r2)

# Create results DataFrame
results_df = pd.DataFrame(results)
results_df
# Out:
#                Model      RMSE  R2_Score
# 0  Linear Regression  0.589458  0.816454
# 1   Ridge Regression  0.589461  0.816452
# 2   Lasso Regression  0.610271  0.803264
# 3      Random Forest  0.422281  0.905802
# 4      Decision Tree  0.592341  0.814654
# 5  Gradient Boosting  0.498602  0.868675
